# %%
import pandas as pd

# %%
import pandas as pd
import os

# Set correct working directory
os.chdir("C:/Users/neha/OneDrive/Desktop/AI-Energy-Forecasting")

# Now load file
df = pd.read_csv("data/energy.csv")
df.head()
# Out:
#          date  energy
# 0  2023-01-01     120
# 1  2023-01-02     130
# 2  2023-01-03     125
# 3  2023-01-04     140
# 4  2023-01-05     150

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\neha\OneDrive\Desktop\AI-Energy-Forecasting\notebooks
